# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import numpy as np


# %matplotlib inline

# %%
worldcities = pd.read_csv('../data/worldcities.csv')
worldcities
# Out:
#               city   city_ascii      lat       lng      country iso2 iso3  \
# 0            Tokyo        Tokyo  35.6839  139.7744        Japan   JP  JPN
# 1          Jakarta      Jakarta  -6.2146  106.8451    Indonesia   ID  IDN
# 2            Delhi        Delhi  28.6667   77.2167        India   IN  IND
# 3           Manila       Manila  14.6000  120.9833  Philippines   PH  PHL
# 4        São Paulo    Sao Paulo -23.5504  -46.6339       Brazil   BR  BRA
# ...            ...          ...      ...       ...          ...  ...  ...
# 42900       Tukchi       Tukchi  57.3670  139.5000       Russia   RU  RUS
# 42901        Numto        Numto  63.6667   71.3333       Russia   RU  RUS
# 42902         Nord         Nord  81.7166  -17.8000    Greenland   GL  GRL
# 42903  Timmiarmiut  Timmiarmiut  62.5333  -42.2167    Greenland   GL  GRL
# 42904      Nordvik      Nordvik  74.0165  111.5100       Russia   RU  RUS
#
#                                      admin_name  capital  population  \
# ...

# %%
us_travel2015 = pd.read_csv('../data/us_citizen_travel_2015.csv', encoding = "ISO-8859-1")
us_travel2015
# Out:
#                Regions     15-Jan     15-Feb     15-Mar     15-Apr     15-May  \
# 0               Europe    585,982    500,982    840,187    926,094  1,339,841
# 1            Caribbean    560,268    610,837    755,526    671,777    647,866
# 2                Asia*    392,463    325,069    439,242    403,753    409,652
# 3        South America    129,211    135,309    154,234    126,276    146,458
# 4      Central America    223,884    230,021    283,876    208,872    207,285
# 5              Oceania     53,439     67,496     61,684     42,818     45,192
# 6          Middle East    162,570    136,853    166,257    145,791    181,811
# 7               Africa     25,125     20,343     27,766     24,945     31,857
# 8                  NaN        NaN        NaN        NaN        NaN        NaN
# 9       Total Overseas  2,132,942  2,026,910  2,728,772  2,550,326  3,009,962
# 10                 NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %%
us_travel2014 = pd.read_csv('../data/us_citizen_travel_2014.csv', encoding = "ISO-8859-1")
us_travel2014
# Out:
#                      Regions     Jan-14     Feb-14     Mar-14     Apr-14  \
# 0                     Europe    577,691    497,003    806,663    868,367
# 1                  Caribbean    498,620    550,203    705,211    629,774
# 2                       Asia    376,296    312,814    397,296    381,817
# 3              South America    127,749    137,612    154,680    123,068
# 4           Central America     219,192    225,540    283,108    213,929
# 5                    Oceania     51,774     62,658     60,097     41,314
# 6                Middle East    140,179    119,192    140,706    141,744
# 7                     Africa     23,982     21,066     27,950     27,596
# 8                        NaN        NaN        NaN        NaN        NaN
# 9         Total Overseas (2)  2,015,483  1,926,088  2,575,711  2,427,609
# 10                       NaN        NaN        NaN        NaN        NaN
# 11  Mexico (Total) (3) (Rev)  2,073,219  1,975,581  2,396,039  2,052,385
# ...

# %%
tourism = pd.read_csv('../data/tourism.csv')
tourism
# Out:
#                  country  tourists_in_millions  receipts_in_billions  \
# 0                 France                 117.1                 35.96
# 1                 Mexico                  51.1                 11.45
# 2          United States                  45.0                 84.21
# 3                  Italy                  38.4                 20.46
# 4                Hungary                  31.6                  4.22
# 5                Croatia                  21.6                  5.63
# 6                 Turkey                  16.0                 13.77
# 7                Austria                  15.1                 15.36
# 8                Germany                  12.4                 58.37
# 9         Virgin Islands                   8.6                  0.69
# 10  United Arab Emirates                   8.1                 24.62
# 11                Greece                   7.4                  6.19
# 12           Netherlands                   7.3                 10.93
# ...

# %%
tourism_departures = pd.read_csv('../data/tourism_departures_bycountry.csv')

# %%
tourism_departures = tourism_departures[['Country Name', 'Country Code', 'Indicator Name',
                                         '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
                                         '2019', '2020']].copy()
tourism_departures
# Out:
#      Country Name Country Code                               Indicator Name  \
# 0           Aruba          ABW  International tourism, number of departures
# 1     Afghanistan          AFG  International tourism, number of departures
# 2          Angola          AGO  International tourism, number of departures
# 3         Albania          ALB  International tourism, number of departures
# 4         Andorra          AND  International tourism, number of departures
# ..            ...          ...                                          ...
# 259        Kosovo          XKX  International tourism, number of departures
# 260   Yemen, Rep.          YEM  International tourism, number of departures
# 261  South Africa          ZAF  International tourism, number of departures
# 262        Zambia          ZMB  International tourism, number of departures
# 263      Zimbabwe          ZWE  International tourism, number of departures
#
# ...

# %%
tourism_departures.to_csv('tourist_depart.csv')

# %%
tourism_arrivals = pd.read_csv('../data/tourism_arrivals_bycountry.csv')
tourism_arrivals = tourism_arrivals[['Country Name', 'Country Code', 'Indicator Name',
                                         '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
                                         '2019', '2020']].copy()
tourism_arrivals
# Out:
#      Country Name Country Code                             Indicator Name  \
# 0           Aruba          ABW  International tourism, number of arrivals
# 1     Afghanistan          AFG  International tourism, number of arrivals
# 2          Angola          AGO  International tourism, number of arrivals
# 3         Albania          ALB  International tourism, number of arrivals
# 4         Andorra          AND  International tourism, number of arrivals
# ..            ...          ...                                        ...
# 259        Kosovo          XKX  International tourism, number of arrivals
# 260   Yemen, Rep.          YEM  International tourism, number of arrivals
# 261  South Africa          ZAF  International tourism, number of arrivals
# 262        Zambia          ZMB  International tourism, number of arrivals
# 263      Zimbabwe          ZWE  International tourism, number of arrivals
#
#           2010       2011       2012       2013       2014       2015  \
# ...

# %%
tourism_arrivals.to_csv('tourist_arrivals.csv')

# %%
country_expenditures = pd.read_csv('../data/country_expenditures.csv')
country_expenditures = country_expenditures[['Country Name', 'Country Code', 'Indicator Name',
                                         '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
                                         '2019', '2020']].copy()
country_expenditures
# Out:
#      Country Name Country Code  \
# 0           Aruba          ABW
# 1     Afghanistan          AFG
# 2          Angola          AGO
# 3         Albania          ALB
# 4         Andorra          AND
# ..            ...          ...
# 259        Kosovo          XKX
# 260   Yemen, Rep.          YEM
# 261  South Africa          ZAF
# 262        Zambia          ZMB
# 263      Zimbabwe          ZWE
#
#                                         Indicator Name          2010  \
# 0    International tourism, expenditures (current US$)  2.610000e+08
# 1    International tourism, expenditures (current US$)  1.060000e+08
# 2    International tourism, expenditures (current US$)  2.750000e+08
# 3    International tourism, expenditures (current US$)  1.452000e+09
# 4    International tourism, expenditures (current US$)           NaN
# ..                                                 ...           ...
# 259  International tourism, expenditures (current US$)           NaN
# ...

# %%
country_expenditures.to_csv('tourism_expenditures.csv')

# %%
bilateral_co2 = pd.read_csv('../data/bilateraltrade_co2.csv')
bilateral_co2
# Out:
#         Year\tOrigin\tDestination\tEmbodiedFlow_GgCO2eq\t
# 0          1990\tAfghanistan\tAfghanistan\t1.151736e+04\t
# 1          1991\tAfghanistan\tAfghanistan\t1.169803e+04\t
# 2          1992\tAfghanistan\tAfghanistan\t1.072155e+04\t
# 3          1993\tAfghanistan\tAfghanistan\t1.076243e+04\t
# 4          1994\tAfghanistan\tAfghanistan\t1.068248e+04\t
# ...                                                   ...
# 1072497     2017\tZimbabwe\tRest of World\t1.483143e+03\t
# 1072498     2018\tZimbabwe\tRest of World\t3.477882e+03\t
# 1072499     2019\tZimbabwe\tRest of World\t2.553395e+03\t
# 1072500     2020\tZimbabwe\tRest of World\t1.928209e+03\t
# 1072501     2021\tZimbabwe\tRest of World\t2.174663e+03\t
#
# [1072502 rows x 1 columns]

# %% [markdown]
# Need to fix the data source above

# %%
epi_2020 = pd.read_csv('../data/2020-epi.csv')
epi_2020
# Out:
#      code  iso               country                     region  EPI.new  \
# 0       4  AFG           Afghanistan              Southern Asia     25.5
# 1      24  AGO                Angola         Sub-Saharan Africa     29.7
# 2       8  ALB               Albania             Eastern Europe     49.0
# 3     784  ARE  United Arab Emirates        Greater Middle East     55.6
# 4      32  ARG             Argentina  Latin America & Caribbean     52.2
# ..    ...  ...                   ...                        ...      ...
# 175   548  VUT               Vanuatu               Asia-Pacific     28.9
# 176   882  WSM                 Samoa               Asia-Pacific     37.3
# 177   710  ZAF          South Africa         Sub-Saharan Africa     43.1
# 178   894  ZMB                Zambia         Sub-Saharan Africa     34.7
# 179   716  ZWE              Zimbabwe         Sub-Saharan Africa     37.0
#
#      HLT.new  AIR.new  PMD.new  HAD.new  OZD.new  ...  NXA.rgn.mean  \
# ...

# %%
epi_2018 = pd.read_csv('../data/2018-epi.csv')
epi_2018
# Out:
#      code  iso              country  EPI.current  HLT.current  AIR.current  \
# 0       4  AFG          Afghanistan        37.74        36.76        44.67
# 1       8  ALB              Albania        65.46        65.67        65.47
# 2      12  DZA              Algeria        57.18        80.95        93.98
# 3      24  AGO               Angola        37.44        33.79        44.66
# 4      28  ATG  Antigua and Barbuda        59.18        76.53        89.13
# ..    ...  ...                  ...          ...          ...          ...
# 175   548  VUT              Vanuatu        44.55        50.46        61.05
# 176   862  VEN            Venezuela        63.89        75.74        90.39
# 177   704  VNM             Viet Nam        46.96        47.12        43.20
# 178   894  ZMB               Zambia        50.97        31.57        41.66
# 179   716  ZWE             Zimbabwe        43.41        40.58        53.52
#
# ...

# %%
epi_2018.to_csv('epi_2018.csv')

# %%
esi_2005 = pd.read_csv('../data/2005-esi-all-countries.csv')
esi_2005
# Out:
#     ISO3Code (v. 10)                     Indicator SYS_AIR SYS_AIR.1  \
# 0                NaN  Country (alphabetical order)     NO2       SO2
# 1                AFG                   Afghanistan      ..        ..
# 2                ALB                       Albania      ..        ..
# 3                DZA                       Algeria      ..        ..
# 4                ASM                American Samoa      ..        ..
# ..               ...                           ...     ...       ...
# 234              WLF     Wallis and Futuna Islands      ..        ..
# 235              ESH                Western Sahara      ..        ..
# 236              YEM                         Yemen      ..        ..
# 237              ZMB                        Zambia      ..        ..
# 238              ZWE                      Zimbabwe      ..        ..
#
#     SYS_AIR.2 SYS_AIR.3  SYS_BIO SYS_BIO.1 SYS_BIO.2 SYS_BIO.3  ... CAP_ST.2  \
# ...

# %%
esi_2005.to_csv('esi_2005.csv')

# %%
railwaylines_bycountry = pd.read_csv('../data/railwaylines_bycountry.csv')
railwaylines_bycountry = railwaylines_bycountry[['Country Name', 'Country Code', 'Indicator Name', 
                                                 '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
                                         '2019', '2020', '2021']].copy()
railwaylines_bycountry
# Out:
#                     Country Name Country Code               Indicator Name  \
# 0                          Aruba          ABW  Rail lines (total route-km)
# 1    Africa Eastern and Southern          AFE  Rail lines (total route-km)
# 2                    Afghanistan          AFG  Rail lines (total route-km)
# 3     Africa Western and Central          AFW  Rail lines (total route-km)
# 4                         Angola          AGO  Rail lines (total route-km)
# ..                           ...          ...                          ...
# 261                       Kosovo          XKX  Rail lines (total route-km)
# 262                  Yemen, Rep.          YEM  Rail lines (total route-km)
# 263                 South Africa          ZAF  Rail lines (total route-km)
# 264                       Zambia          ZMB  Rail lines (total route-km)
# 265                     Zimbabwe          ZWE  Rail lines (total route-km)
#
# ...

# %%
railwaylines_bycountry.to_csv('railways_country.csv')

# %%
railpassengers_bycountry = pd.read_csv('../data/railway_passengers_bycountry.csv')
railpassengers_bycountry = railpassengers_bycountry[['Country Name', 'Country Code', 'Indicator Name', 
                                                 '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
                                         '2019', '2020', '2021']].copy()
railpassengers_bycountry
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                                         Indicator Name  2011  2012  2013  \
# 0    Railways, passengers carried (million passenge...   NaN   NaN   NaN
# 1    Railways, passengers carried (million passenge...   NaN   NaN   NaN
# 2    Railways, passengers carried (million passenge...   NaN   NaN   NaN
# 3    Railways, passengers carried (million passenge...   NaN   NaN   NaN
# ...

# %%
railpassengers_bycountry.to_csv('railpassengers_countries.csv')
